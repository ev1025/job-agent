# %%
from google import genai
from google.genai import types

parsing_prompt="안녕하세요"

client = genai.Client(api_key="AIzaSyCgcPcXOA2o62nf4ZMT9Bg_1TI9TX_cipQ")
chat = client.chats.create(model="gemini-2.5-flash",
                           config=types.GenerateContentConfig(system_instruction=parsing_prompt))


response = chat.send_message("오늘 날씨 어때")
print(response.text)

response = chat.send_message("내일 날씨 어때")
print(response.text)

for message in chat.get_history():
    print(f'role - {message.role}',end=": ")
    print(message.parts[0].text)
# Out:
# 안녕하세요! 오늘 날씨 정보가 필요하시군요.
#
# 하지만 제가 어느 지역의 날씨를 알려드려야 할지 알 수 없어서요. **어느 지역의 날씨가 궁금하신가요?**
#
# 예를 들어 '서울 날씨', '부산 해운대 날씨'처럼 지역명을 말씀해주시면 제가 현재 날씨와 예보를 찾아드릴 수 있어요!
# 내일 날씨를 알고 싶으시군요! 😊
#
# 하지만 제가 어느 지역의 내일 날씨를 알려드려야 할지 알 수 없어서요. 날씨는 지역마다 달라서 **어느 지역의 내일 날씨가 궁금하신지 알려주셔야 해요.**
#
# 예를 들어 '서울 내일 날씨', '부산 내일 날씨', '제주도 내일 날씨'처럼 지역명을 말씀해주시면 제가 바로 찾아드릴 수 있습니다!
# role - user: 오늘 날씨 어때
# role - model: 안녕하세요! 오늘 날씨 정보가 필요하시군요.
#
# 하지만 제가 어느 지역의 날씨를 알려드려야 할지 알 수 없어서요. **어느 지역의 날씨가 궁금하신가요?**
#
# 예를 들어 '서울 날씨', '부산 해운대 날씨'처럼 지역명을 말씀해주시면 제가 현재 날씨와 예보를 찾아드릴 수 있어요!
# role - user: 내일 날씨 어때
# role - model: 내일 날씨를 알고 싶으시군요! 😊
#
# 하지만 제가 어느 지역의 내일 날씨를 알려드려야 할지 알 수 없어서요. 날씨는 지역마다 달라서 **어느 지역의 내일 날씨가 궁금하신지 알려주셔야 해요.**
#
# 예를 들어 '서울 내일 날씨', '부산 내일 날씨', '제주도 내일 날씨'처럼 지역명을 말씀해주시면 제가 바로 찾아드릴 수 있습니다!

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
from google.genai import types

import vertexai
from vertexai.preview import rag
from vertexai.generative_models import GenerativeModel, Tool
from datetime import datetime

import json
import os
import uvicorn

# Pydantic 모델 정의 (JSON 페이로드를 받기 위해)
class QuestionRequest(BaseModel):
    question: str

# FastAPI 앱 생성
app = FastAPI()

PROJECT_ID = "job-agent-471006"
LOCATION = "us-east4"  # RAG corpus가 있는 지역과 일치
CORPUS_NAME = f"projects/{PROJECT_ID}/locations/{LOCATION}/ragCorpora/3458764513820540928"
MODEL_ID = "gemini-2.0-flash-001"
similarity_top_k = 10
vector_distance_threshold = 0.5

system_prompt = f"""
### **명령 (Instruction)**
당신은 사용자의 요청에 맞춰 최적의 채용 공고를 추천하는 전문 IT 커리어 컨설턴트입니다.
RAG 시스템을 통해 검색된 채용 공고 문서들을 바탕으로 아래 조건에 맞는 답변을 생성해주세요.

### **출력 조건 (Output Constraints)**
1.  검색된 공고 중 **사용자 질의와 관련성이 높은 공고**만 선정해주세요.
2.  선정한 공고들을 아래 **Markdown 테이블 형식**으로 요약해주세요.
3.  테이블 아래에, 각 공고를 **추천하는 이유**를 2~3 문장으로 간략하게 설명해주세요.

### **출력 형식 (Output Format)**
**추천 채용 공고**

| 회사명 | 채용 제목 | 경력 조건 | 마감일 | 채용공고 |
|---|---|---|---|---|
| [회사명] | [채용 제목] | [경력 조건] | [마감일] | [채용공고]([실제 URL 주소]) |
| [회사명] | [채용 제목] | [경력 조건] | [마감일] | [채용공고]([실제 URL 주소]) |

- **[회사명]:** [추천 이유 설명]
- **[회사명]:** [추천 이유 설명]
"""

def query_rebuilder(question: str, MODEL_ID=MODEL_ID):
    parsing_prompt = f"""
    당신은 채용 공고 검색 시스템의 쿼리 분석 전문가입니다.
    사용자의 질문을 분석하여, 검색 시스템이 즉시 사용할 수 있는 JSON을 생성해주세요.

    # 사용 가능한 필드 (structData keys):
    - deadline_date (YYYY-MM-DD 형식 또는 '상시채용', '채용시')
    - posted_date (YYYY-MM-DD 형식)
    - location (문자열, 예: "서울 송파구")
    - experience (문자열, 예: "신입", "경력 3년 이상")
    - employment_type (문자열, 예: "정규직", "계약직")
    - company (문자열)

    # 지침:
    1. 질문의 핵심 내용을 'keywords'로 추출합니다.
    2. 질문에 포함된 필터 조건을 분석하여 'filter_string'을 생성합니다.
    3. 'filter_string'은 SQL의 WHERE 절과 유사하며, 'AND'로 조건을 연결합니다.
    4. 오늘 날짜는 '{datetime.now().strftime('%Y-%m-%d')}'입니다. 이를 기준으로 '올해', 내일', '이번 주', '다음 주' 등을 계산하여 'deadline_date' 필터를 YYYY-MM-DD 형식으로 정확하게 만드세요.
    5. 필터링 조건이 없으면 'filter_string'은 빈 문자열("")로 두세요.
    6. '9월'과 같은 월 단위 질문은 해당 월의 1일부터 마지막 날까지의 범위로 해석합니다. 사용자가 '마감일'인지 '등록일'인지 명확히 언급하지 않으면, 문맥상 더 자연스러운 필드를 선택하세요.
    
    # 예시 1
    질문: "다음 주 월요일까지 마감되는 서울 지역 파이썬 신입 공고 찾아줘"
    JSON:
    {{
      "keywords": "파이썬 신입 공고",
      "filter_string": "location = \\"서울\\" AND experience = \\"신입\\" AND deadline_date <= \\"2025-09-22\\""
    }}

    # 예시 2
    질문: "RAG 관련 공고 그냥 다 보여줘"
    JSON:
    {{
      "keywords": "RAG",
      "filter_string": ""
    }}
    
    # 실제 질문
    질문: "{question}"
    JSON:
    """
    client = GenerativeModel(model_name=MODEL_ID,
                             system_instruction=parsing_prompt)
    
    response = client.generate_content(
        contents=question)

    
    structured_query_str = response.text.strip().replace("```json", "").replace("```", "")
    structured_query = json.loads(structured_query_str)
    
    search_keywords = structured_query.get("keywords", question)
    final_filter_string = structured_query.get("filter_string", "")
    
    return search_keywords + final_filter_string

def vertex_init(PROJECT_ID=PROJECT_ID, LOCATION=LOCATION):
    vertexai.init(project=PROJECT_ID, location=LOCATION)

def rerank_model(question: str, CORPUS_NAME=CORPUS_NAME, MODEL_ID=MODEL_ID,
                 similarity_top_k=similarity_top_k, system_prompt=system_prompt):
    vertex_init()
    config = rag.RagRetrievalConfig(
        top_k=similarity_top_k,
        ranking=rag.Ranking(
            rank_service=rag.RankService(
                model_name="semantic-ranker-default@latest",
            )
        )
    )
    
    rag_retrieval_tool = Tool.from_retrieval(
        retrieval=rag.Retrieval(
            source=rag.VertexRagStore(
                rag_resources=[
                    rag.RagResource(
                        rag_corpus=CORPUS_NAME,
                    )
                ],
                rag_retrieval_config=config
            ),
        )
    )
    
    rag_model = GenerativeModel(
        model_name=MODEL_ID,
        tools=[rag_retrieval_tool],
        system_instruction=system_prompt
    )
    
    chat = rag_model.start_chat()
    
    pre_question =query_rebuilder(question)
    
    response = chat.send_message(pre_question)
    
    return response

# %%
mes = rerank_model("LLM 공고 보여줘")
mes
# Out:
# c:\Users\ENVY\Desktop\job-agent\venv\Lib\site-packages\vertexai\generative_models\_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()
# candidates {
#   content {
#     role: "model"
#     parts {
#       text: "**추천 채용 공고**\n\n| 회사명 | 채용 제목 | 경력 조건 | 마감일 | 채용공고 |\n|---|---|---|---|---|\n| (주)이스트소프트 | LLM 기반 영상 번역 서비스 개발 | 경력 3~20년 | ~ 10/08(수) | [채용공고](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51781488&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699) |\n| (주)리앤파트너 | [국내 LegalTech기업] AI LLM 백엔드 개발자 대리급 | 경력 3~5년 | 2025/09/20 | [채용공고](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51754147&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=8989709f-86cd-40ad-b658-720d11158dc5) |\n| 법무법인와이케이 | [국내 TOP7 로펌 - 법무법인YK] AI 개발자 채용 | 신입·경력 | ~ 10/09(목) | [채용공고](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51783985&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699) |\n| 특허법인 차원(Chawon IP Law Firm) | [특허조사분석] (신입/경력) 특허조사분석/기술사업화 채용 | 경력무관 | ~ 10/08(수) | [채용공고](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51769355&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=b62ae756-8db4-433b-9e87-2882f6c3f521) |\n\n- **(주)이스트소프트:** LLM을 기반으로 영상 번역 서비스 개발자를 채용하며, LLM 관련 경력을 활용할 수 있습니다.\n- **(주)리앤파트너:** LegalTech 기업에서 AI LLM 백엔드 개발자를 채용하며, Django 기반 웹서비스와 연동되는 LLM & RAG 기반 파이프라인 설계 경험을 쌓을 수 있습니다.\n- **법무법인와이케이:** 국내 TOP7 로펌에서 AI 개발자를 채용하며, 법률 AI를 다뤄본 경험이 있다면 더욱 유리합니다.\n- **특허법인 차원(Chawon IP Law Firm):** 특허조사분석 및 기술사업화 채용으로, 챗GPT, 제미나이, 클로드 등 LLM 활용 능숙자를 우대합니다.\n"
#     }
#   }
#   finish_reason: STOP
#   grounding_metadata {
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_7.jsonl"
#         title: "job_data_part_7.jsonl"
#         text: "id 51783985\nstructData title [국내 TOP7 로펌 - 법무법인YK] AI 개발자 채용\nstructData company 법무법인와이케이\nstructData location 서울 강남구\nstructData experience 신입·경력\nstructData employment_type 정규직\nstructData posted_date 2025-09-09\nstructData deadline_date ~ 10/09(목)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51783985&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699\ncontent [국내 TOP7 로펌 - 법무법인YK] AI 개발자 채용\n\n[국내 TOP7 로펌 - 법무법인YK]\nLegal Tech -\nAI 개발자 채용\n모집분야\n📋\n담당업무\n• Legal Tech 자연어 처리 (NLP) 기술\n📋\n필수사항\n자연어 처리 경험 3년 이상\nAPI 기반 AI 서비스를 구현해 본 경험이 있으신 분\nLLM 학습 및 fine-tuning 경험이 있으신 분\nLLM 기반 서비스 상용화에 필요한 요건을 분석한 경험이 있으신 분\n새로운 기술과 도구를 배우고 적용하는데 두려움이 없으신 분\n문제 해결 과정을 즐기고 고객과의 의사소통 및 협업을 중요하게 여기는 분\n📋\n우대사항\n최신 LLM 기술 동향 파악 및 SOTA 알고리즘 적용 경험\n법률 도메인 지식 보유\n법률 AI를 다뤄본 경험\n🏠 근무조건\n• 고용형태 :\n정규직\n(수습기간 : 6개월, 수습기간 종료 전 평가 후 채용여부 확정)\n• 급여 :\n면접 후 결정\n• 근무지 :\n서울 강남구 테헤란로 103\n🎁 복지 및 혜택\n🚀 채용절차\n접수기간 :\n2025-09-09 14시 ~ 2025-10-09 24시\n제출서류 :\n사람인 온라인 이력서\n접수방법 :\n사람인 입사지원\n전형절차 :\n서류전형 → 1차면접 → 최종합격\n🛎️ 유의사항\n• 입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다."
#         rag_chunk {
#           text: "id 51783985\nstructData title [국내 TOP7 로펌 - 법무법인YK] AI 개발자 채용\nstructData company 법무법인와이케이\nstructData location 서울 강남구\nstructData experience 신입·경력\nstructData employment_type 정규직\nstructData posted_date 2025-09-09\nstructData deadline_date ~ 10/09(목)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51783985&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699\ncontent [국내 TOP7 로펌 - 법무법인YK] AI 개발자 채용\n\n[국내 TOP7 로펌 - 법무법인YK]\nLegal Tech -\nAI 개발자 채용\n모집분야\n📋\n담당업무\n• Legal Tech 자연어 처리 (NLP) 기술\n📋\n필수사항\n자연어 처리 경험 3년 이상\nAPI 기반 AI 서비스를 구현해 본 경험이 있으신 분\nLLM 학습 및 fine-tuning 경험이 있으신 분\nLLM 기반 서비스 상용화에 필요한 요건을 분석한 경험이 있으신 분\n새로운 기술과 도구를 배우고 적용하는데 두려움이 없으신 분\n문제 해결 과정을 즐기고 고객과의 의사소통 및 협업을 중요하게 여기는 분\n📋\n우대사항\n최신 LLM 기술 동향 파악 및 SOTA 알고리즘 적용 경험\n법률 도메인 지식 보유\n법률 AI를 다뤄본 경험\n🏠 근무조건\n• 고용형태 :\n정규직\n(수습기간 : 6개월, 수습기간 종료 전 평가 후 채용여부 확정)\n• 급여 :\n면접 후 결정\n• 근무지 :\n서울 강남구 테헤란로 103\n🎁 복지 및 혜택\n🚀 채용절차\n접수기간 :\n2025-09-09 14시 ~ 2025-10-09 24시\n제출서류 :\n사람인 온라인 이력서\n접수방법 :\n사람인 입사지원\n전형절차 :\n서류전형 → 1차면접 → 최종합격\n🛎️ 유의사항\n• 입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다."
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_7.jsonl"
#         title: "job_data_part_7.jsonl"
#         text: "id 51781488\nstructData title LLM 기반 영상 번역 서비스 개발\nstructData company (주)이스트소프트\nstructData location 서울 서초구\nstructData experience 경력 3~20년\nstructData employment_type 정규직\nstructData posted_date 2025-09-09\nstructData deadline_date ~ 10/08(수)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51781488&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699"
#         rag_chunk {
#           text: "id 51781488\nstructData title LLM 기반 영상 번역 서비스 개발\nstructData company (주)이스트소프트\nstructData location 서울 서초구\nstructData experience 경력 3~20년\nstructData employment_type 정규직\nstructData posted_date 2025-09-09\nstructData deadline_date ~ 10/08(수)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51781488&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699"
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_5.jsonl"
#         title: "job_data_part_5.jsonl"
#         text: "id 51754147\nstructData title [국내  LegalTech기업] AI LLM 백엔드 개발자 대리급\nstructData company (주)리앤파트너\nstructData location 서울 서초구\nstructData experience 경력 3~5년\nstructData employment_type 정규직\nstructData posted_date 2025-09-05\nstructData deadline_date 2025/09/20\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51754147&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=8989709f-86cd-40ad-b658-720d11158dc5\ncontent [국내  LegalTech기업] AI LLM 백엔드 개발자 대리급\n\n[국내 LegalTech기업]\nAI LLM 백엔드 개발자\n대리급\n모집분야\nAI LLM 백엔드 개발자 대리급\n📋 주요업무\n▣AI LLM 백엔드 개발자 대리급\n•리걸테크 AI 서비스(계약/자문/소송 등) 기능 개발 및 최적화\n•Django 기반 웹서비스와 연동되는 LLM & RAG 기반 파이프라인 설계\n•온프레미스 환경에서 자체 LLM 운영 및 최적화\n•벡터 DB 기반 문서 검색/질의응답 시스템 구축 및 운영\n▣ 자격사항\n•경력 3년 이상 ~ 5년 이하\n•컴퓨터공학 및 소프트웨어 전공자\n•최신 LLM 관련 기술들을 기반으로 한 AI Agent 시스템 설계 및 구현 경험\n•Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험\n•문제 정의부터 AI 모델 설계, 평가, 제품 적용까지 최적화를 위한 전 과정을 주도해 본 경험\n•온프레미스 환경에서 자체 LLM 또는 오픈소스 LLM 운영 및 서빙 경험\n▣ 우대사항\n•Django, FastAPI 등 Python 웹 프레임워크와 LLM 연동 개발 경험\n•Llama2, Mistral, DeepSpeed, vLLM 등 오픈소스 LLM 최적화/커스터마이징 경험\n•elasticsearch, ChromaDB 등 벡터 DB 구축 및 운영 경험\n•GPU 기반 모델 서빙 및 최적화 경험 (Ollama, vLLM 등)\n•LLM 서비스 개발을 위한 데이터 수집, 전처리, 분석 및 인사이트 도출 경험\n•법률 도메인 데이터 전처리 및 특화 LLM 서비스 개발 경험\n▣ 지원방법\n- e-mail 접수 : kubota@leenpartner.com\n- MS워드로 된 국문이력서 및 경력기술서\n- 담당자 : 이영민 본부장 / 010-9134-8796\n• 대리 직급으로 함께할 예정이에요."
#         rag_chunk {
#           text: "id 51754147\nstructData title [국내  LegalTech기업] AI LLM 백엔드 개발자 대리급\nstructData company (주)리앤파트너\nstructData location 서울 서초구\nstructData experience 경력 3~5년\nstructData employment_type 정규직\nstructData posted_date 2025-09-05\nstructData deadline_date 2025/09/20\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51754147&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=8989709f-86cd-40ad-b658-720d11158dc5\ncontent [국내  LegalTech기업] AI LLM 백엔드 개발자 대리급\n\n[국내 LegalTech기업]\nAI LLM 백엔드 개발자\n대리급\n모집분야\nAI LLM 백엔드 개발자 대리급\n📋 주요업무\n▣AI LLM 백엔드 개발자 대리급\n•리걸테크 AI 서비스(계약/자문/소송 등) 기능 개발 및 최적화\n•Django 기반 웹서비스와 연동되는 LLM & RAG 기반 파이프라인 설계\n•온프레미스 환경에서 자체 LLM 운영 및 최적화\n•벡터 DB 기반 문서 검색/질의응답 시스템 구축 및 운영\n▣ 자격사항\n•경력 3년 이상 ~ 5년 이하\n•컴퓨터공학 및 소프트웨어 전공자\n•최신 LLM 관련 기술들을 기반으로 한 AI Agent 시스템 설계 및 구현 경험\n•Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험\n•문제 정의부터 AI 모델 설계, 평가, 제품 적용까지 최적화를 위한 전 과정을 주도해 본 경험\n•온프레미스 환경에서 자체 LLM 또는 오픈소스 LLM 운영 및 서빙 경험\n▣ 우대사항\n•Django, FastAPI 등 Python 웹 프레임워크와 LLM 연동 개발 경험\n•Llama2, Mistral, DeepSpeed, vLLM 등 오픈소스 LLM 최적화/커스터마이징 경험\n•elasticsearch, ChromaDB 등 벡터 DB 구축 및 운영 경험\n•GPU 기반 모델 서빙 및 최적화 경험 (Ollama, vLLM 등)\n•LLM 서비스 개발을 위한 데이터 수집, 전처리, 분석 및 인사이트 도출 경험\n•법률 도메인 데이터 전처리 및 특화 LLM 서비스 개발 경험\n▣ 지원방법\n- e-mail 접수 : kubota@leenpartner.com\n- MS워드로 된 국문이력서 및 경력기술서\n- 담당자 : 이영민 본부장 / 010-9134-8796\n• 대리 직급으로 함께할 예정이에요."
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_6.jsonl"
#         title: "job_data_part_6.jsonl"
#         text: "id 51778836\nstructData title 에너지 대기업 변호사 포지션\nstructData company (주)스카우트파트너스\nstructData location 경기 성남시 분당구\nstructData experience 경력 3~7년\nstructData employment_type 정규직\nstructData posted_date 2025-09-09\nstructData deadline_date ~ 09/20(토)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51778836&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699\ncontent 에너지 대기업 변호사 포지션\n\n에너지 대기업 변호사 포지션\n모집분야\n변호사\n(0명)\n📋 주요업무\n[직무소개]\n해외법무 이슈에 대한 전반적인 업무를 담당\n[주요역할]\n- 회사 Biz 관련 법률 검토 및 보고서 작성\n- 로펌과 연계하여 주요 프로젝트 수행\n[주요업무]\nㆍ해외법무 업무: 영문 계약 검토 및 법률 자문 등\nㆍ해외 PJT 지원: JV, 전략적 투자 등\nㆍ해외 Claim/소송 등 분쟁대응\nㆍ자회사 지원\n[자격요건]\n- 경력 3년 이상 ~ 6년 이하\n- 국내외 변호사 자격을 보유하신 분\n- 한국변호사 자격으로 해외법무 경험하신 분 선호\n- 전문분야 외 영역에 대한 빠른 업무/지식습득 능력 보유하신 분\n- 미국 JD/LLM 또는 한국 Law School 학위\n- 외국어 능력 우수자 우대\n📋 자격요건\n• 경력 3년 이상 ~ 7년 이하\n• 석사졸업이상\n🏠 근무조건\n• 고용형태 :\n정규직\n• 급여 :\n면접 후 결정\n• 근무지 :\n경기 성남시 분당구 판교로 20\n🎁 복지 및 혜택\n🚀 채용절차\n접수기간 :\n2025-09-09 08시 ~ 2025-09-20 24시\n제출서류 :\n사람인 온라인 이력서\n접수방법 :\n사람인 입사지원\n전형절차 :\n서류전형 → 1차면접 → 최종합격\n🛎️ 유의사항\n• 입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.\n• 모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."
#         rag_chunk {
#           text: "id 51778836\nstructData title 에너지 대기업 변호사 포지션\nstructData company (주)스카우트파트너스\nstructData location 경기 성남시 분당구\nstructData experience 경력 3~7년\nstructData employment_type 정규직\nstructData posted_date 2025-09-09\nstructData deadline_date ~ 09/20(토)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51778836&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699\ncontent 에너지 대기업 변호사 포지션\n\n에너지 대기업 변호사 포지션\n모집분야\n변호사\n(0명)\n📋 주요업무\n[직무소개]\n해외법무 이슈에 대한 전반적인 업무를 담당\n[주요역할]\n- 회사 Biz 관련 법률 검토 및 보고서 작성\n- 로펌과 연계하여 주요 프로젝트 수행\n[주요업무]\nㆍ해외법무 업무: 영문 계약 검토 및 법률 자문 등\nㆍ해외 PJT 지원: JV, 전략적 투자 등\nㆍ해외 Claim/소송 등 분쟁대응\nㆍ자회사 지원\n[자격요건]\n- 경력 3년 이상 ~ 6년 이하\n- 국내외 변호사 자격을 보유하신 분\n- 한국변호사 자격으로 해외법무 경험하신 분 선호\n- 전문분야 외 영역에 대한 빠른 업무/지식습득 능력 보유하신 분\n- 미국 JD/LLM 또는 한국 Law School 학위\n- 외국어 능력 우수자 우대\n📋 자격요건\n• 경력 3년 이상 ~ 7년 이하\n• 석사졸업이상\n🏠 근무조건\n• 고용형태 :\n정규직\n• 급여 :\n면접 후 결정\n• 근무지 :\n경기 성남시 분당구 판교로 20\n🎁 복지 및 혜택\n🚀 채용절차\n접수기간 :\n2025-09-09 08시 ~ 2025-09-20 24시\n제출서류 :\n사람인 온라인 이력서\n접수방법 :\n사람인 입사지원\n전형절차 :\n서류전형 → 1차면접 → 최종합격\n🛎️ 유의사항\n• 입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.\n• 모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_3.jsonl"
#         title: "job_data_part_3.jsonl"
#         text: "id 51698034\nstructData title 사내 변호사/(1~ 7년)/(대형 로펌 우대) - 종합상사(코스피)\nstructData company 그레이스앤파트너스(주)\nstructData location 서울 강남구\nstructData experience 경력 1~7년\nstructData employment_type 정규직\nstructData posted_date 2025-08-30\nstructData deadline_date 2025/09/14\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51698034&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=60b887fa-79bf-4778-88c3-636e3d0673a3\ncontent 사내 변호사/(1~ 7년)/(대형 로펌 우대) - 종합상사(코스피)\n\n사내 변호사/(1~ 7년)/(대형 로펌 우대) - 종합상사(코스피)\n모집분야\n사내 변호사/(1~ 7년)\n(0명)\n📋 주요업무\n• 국내/외 투자 및 M&A 관련 법률실사, 계약검토, 법률자문, 협상 지원\n• 분쟁/클레임 대응, 소송/중재 등 송무\n• 국내/외 계약검토 및 법률자문\n📋 자격요건\n• 국내/외 변호사 자격증을 소지하신 분 (LLB, LLM, JD 등)\n• 비즈니스 영어 가능자\n📋 우대사항\n• 글로벌 기업 법무팀 또는 대형 로펌 근무 경력 보유자\n• 해외 Project 및 소송 유경험자\n• 영미권 거주 경험자\n📋 기타사항\n• 고용형태 : 정규직\n• 근무지: 서울 본사\n• 연봉: 흡족하게 협의/ 역량 우수하신분만\n• 문의: 010-7565-8488/ lhy@gracenpartners.com\n🏠 근무조건\n• 고용형태 :\n정규직\n• 급여 :\n면접 후 결정\n• 근무지 : 서울\n🎁 복지 및 혜택\n🚀 채용절차\n접수기간 :\n2025-07-10 12시 ~ 2025-08-09 24시\n제출서류 :\n사람인 온라인 이력서\n접수방법 :\n사람인 입사지원\n전형절차 :\n서류전형 → 1차면접 → 최종합격\n🛎️ 유의사항\n• 입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.\n• 모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."
#         rag_chunk {
#           text: "id 51698034\nstructData title 사내 변호사/(1~ 7년)/(대형 로펌 우대) - 종합상사(코스피)\nstructData company 그레이스앤파트너스(주)\nstructData location 서울 강남구\nstructData experience 경력 1~7년\nstructData employment_type 정규직\nstructData posted_date 2025-08-30\nstructData deadline_date 2025/09/14\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51698034&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=60b887fa-79bf-4778-88c3-636e3d0673a3\ncontent 사내 변호사/(1~ 7년)/(대형 로펌 우대) - 종합상사(코스피)\n\n사내 변호사/(1~ 7년)/(대형 로펌 우대) - 종합상사(코스피)\n모집분야\n사내 변호사/(1~ 7년)\n(0명)\n📋 주요업무\n• 국내/외 투자 및 M&A 관련 법률실사, 계약검토, 법률자문, 협상 지원\n• 분쟁/클레임 대응, 소송/중재 등 송무\n• 국내/외 계약검토 및 법률자문\n📋 자격요건\n• 국내/외 변호사 자격증을 소지하신 분 (LLB, LLM, JD 등)\n• 비즈니스 영어 가능자\n📋 우대사항\n• 글로벌 기업 법무팀 또는 대형 로펌 근무 경력 보유자\n• 해외 Project 및 소송 유경험자\n• 영미권 거주 경험자\n📋 기타사항\n• 고용형태 : 정규직\n• 근무지: 서울 본사\n• 연봉: 흡족하게 협의/ 역량 우수하신분만\n• 문의: 010-7565-8488/ lhy@gracenpartners.com\n🏠 근무조건\n• 고용형태 :\n정규직\n• 급여 :\n면접 후 결정\n• 근무지 : 서울\n🎁 복지 및 혜택\n🚀 채용절차\n접수기간 :\n2025-07-10 12시 ~ 2025-08-09 24시\n제출서류 :\n사람인 온라인 이력서\n접수방법 :\n사람인 입사지원\n전형절차 :\n서류전형 → 1차면접 → 최종합격\n🛎️ 유의사항\n• 입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.\n• 모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_2.jsonl"
#         title: "job_data_part_2.jsonl"
#         text: "id 51648867\nstructData title [화장품 브랜드] 해외영업/마케팅 채용공고 (해외MD)\nstructData company (주)라콤\nstructData location 서울 송파구\nstructData experience 경력무관\nstructData employment_type 정규직\nstructData posted_date 2025-08-25\nstructData deadline_date ~ 09/24(수)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51648867&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=94d5674b-7f1e-4c2e-b159-b9a53c9b0c4b"
#         rag_chunk {
#           text: "id 51648867\nstructData title [화장품 브랜드] 해외영업/마케팅 채용공고 (해외MD)\nstructData company (주)라콤\nstructData location 서울 송파구\nstructData experience 경력무관\nstructData employment_type 정규직\nstructData posted_date 2025-08-25\nstructData deadline_date ~ 09/24(수)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51648867&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=94d5674b-7f1e-4c2e-b159-b9a53c9b0c4b"
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_6.jsonl"
#         title: "job_data_part_6.jsonl"
#         text: "id 51769355\nstructData title [특허조사분석] (신입/경력) 특허조사분석/기술사업화 채용\nstructData company 특허법인 차원(Chawon IP Law Firm)\nstructData location 서울 강남구\nstructData experience 경력무관\nstructData employment_type 정규직\nstructData posted_date 2025-09-08\nstructData deadline_date ~ 10/08(수)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51769355&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=b62ae756-8db4-433b-9e87-2882f6c3f521\ncontent [특허조사분석] (신입/경력) 특허조사분석/기술사업화 채용\n\n저희는 2025년 6월 “차원이 다른 전략과 실행”을 모토로 새롭게 출범한 특허법인입니다.\n신생 법인이지만, 15년 이상의 경력을 보유한 변리사들이 다수 소속되어 있으며,\n실무에 능숙한 경력직 직원들이 팀을 이뤄 이미 안정적인 업무 기반을 구축하고 있습니다.\n비록 신설 법인이지만, 구성원들의 풍부한 경력과 안정된 운영 체계를 바탕으로 빠르게 자리 잡아가고 있습니다.\n이번 채용은 특허조사분석 및 기술사업화 업무의 사세 확장을 위한 충원으로,\n경험과 책임감을 바탕으로 함께 성장해 나갈 역량 있는 분들의 많은 지원을 기다립니다.\n[모집분야] 특허조사분석\n[주요업무]\n- 특허조사분석, 기술사업화 제반 업무(컨설팅)\n- 제안서 작성 지원, 보고서 및 발표자료 작성 주도\n- 주관기관(PM) 및 고객사 커뮤니케이션\n- 사업관리시스템 서류 작성 및 대응 업무 전반\n[자격요건]\n- 성실하고 책임감 있게 업무를 수행할 수 있는 분\n- 꼼꼼하고 일정 관리 역량 뛰어나신 분\n[우대사항]\n- 특허조사분석 업무 경력이 1년 이상인 분을 우대합니다.\n- 챗GPT, 제미나이, 클로드 등 LLM, HWP, Excel, Power Point에 능숙하신 분을 우대합니다.\n- 한국특허전략개발원, 한국지식재산보호원, 한국발명진흥회, 지역RIPC 등 과제 수행 경험을 보유하신 분을 우대합니다.\n- 특허조사분석, 기술사업화 유관 자격증을 보유하신 분을 우대합니다.\n- 전기전자/정보통신/기계 기술분야에 대한 이해도가 높은 분을 선호합니다.\n- 영어 어학능력 우수자 우대합니다."
#         rag_chunk {
#           text: "id 51769355\nstructData title [특허조사분석] (신입/경력) 특허조사분석/기술사업화 채용\nstructData company 특허법인 차원(Chawon IP Law Firm)\nstructData location 서울 강남구\nstructData experience 경력무관\nstructData employment_type 정규직\nstructData posted_date 2025-09-08\nstructData deadline_date ~ 10/08(수)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51769355&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=b62ae756-8db4-433b-9e87-2882f6c3f521\ncontent [특허조사분석] (신입/경력) 특허조사분석/기술사업화 채용\n\n저희는 2025년 6월 “차원이 다른 전략과 실행”을 모토로 새롭게 출범한 특허법인입니다.\n신생 법인이지만, 15년 이상의 경력을 보유한 변리사들이 다수 소속되어 있으며,\n실무에 능숙한 경력직 직원들이 팀을 이뤄 이미 안정적인 업무 기반을 구축하고 있습니다.\n비록 신설 법인이지만, 구성원들의 풍부한 경력과 안정된 운영 체계를 바탕으로 빠르게 자리 잡아가고 있습니다.\n이번 채용은 특허조사분석 및 기술사업화 업무의 사세 확장을 위한 충원으로,\n경험과 책임감을 바탕으로 함께 성장해 나갈 역량 있는 분들의 많은 지원을 기다립니다.\n[모집분야] 특허조사분석\n[주요업무]\n- 특허조사분석, 기술사업화 제반 업무(컨설팅)\n- 제안서 작성 지원, 보고서 및 발표자료 작성 주도\n- 주관기관(PM) 및 고객사 커뮤니케이션\n- 사업관리시스템 서류 작성 및 대응 업무 전반\n[자격요건]\n- 성실하고 책임감 있게 업무를 수행할 수 있는 분\n- 꼼꼼하고 일정 관리 역량 뛰어나신 분\n[우대사항]\n- 특허조사분석 업무 경력이 1년 이상인 분을 우대합니다.\n- 챗GPT, 제미나이, 클로드 등 LLM, HWP, Excel, Power Point에 능숙하신 분을 우대합니다.\n- 한국특허전략개발원, 한국지식재산보호원, 한국발명진흥회, 지역RIPC 등 과제 수행 경험을 보유하신 분을 우대합니다.\n- 특허조사분석, 기술사업화 유관 자격증을 보유하신 분을 우대합니다.\n- 전기전자/정보통신/기계 기술분야에 대한 이해도가 높은 분을 선호합니다.\n- 영어 어학능력 우수자 우대합니다."
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_6.jsonl"
#         title: "job_data_part_6.jsonl"
#         text: "id 51767488\nstructData title 렉스젠(주)전문연구요원(병역특례) 모집\nstructData company 렉스젠(주)\nstructData location 경기 안양시 동안구\nstructData experience 경력무관\nstructData employment_type 정규직·전문연구요원\nstructData posted_date 2025-09-08\nstructData deadline_date 2025/10/08\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51767488&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=8989709f-86cd-40ad-b658-720d11158dc5"
#         rag_chunk {
#           text: "id 51767488\nstructData title 렉스젠(주)전문연구요원(병역특례) 모집\nstructData company 렉스젠(주)\nstructData location 경기 안양시 동안구\nstructData experience 경력무관\nstructData employment_type 정규직·전문연구요원\nstructData posted_date 2025-09-08\nstructData deadline_date 2025/10/08\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51767488&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=8989709f-86cd-40ad-b658-720d11158dc5"
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_1.jsonl"
#         title: "job_data_part_1.jsonl"
#         text: "id 51547954\nstructData title [신입,경력] 프론트엔드 개발자 채용 (업계 상위 연봉)\nstructData company (주)퀀터스테크놀로지스\nstructData location 서울 강남구\nstructData experience 경력무관\nstructData employment_type 정규직\nstructData posted_date 2025-09-12\nstructData deadline_date ~ 09/30(화)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51547954&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=43fc6227-2529-4154-920e-be908af2d8b4\ncontent [신입,경력] 프론트엔드 개발자 채용 (업계 상위 연봉)\n\n[신입,경력] 프론트엔드 개발자 채용 (업계 상위 연봉)\n모집분야\n[마이크로소프트 MOU 계약 기사 보기]\n🛎️ 유의사항\n• 입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.\n• 모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."
#         rag_chunk {
#           text: "id 51547954\nstructData title [신입,경력] 프론트엔드 개발자 채용 (업계 상위 연봉)\nstructData company (주)퀀터스테크놀로지스\nstructData location 서울 강남구\nstructData experience 경력무관\nstructData employment_type 정규직\nstructData posted_date 2025-09-12\nstructData deadline_date ~ 09/30(화)\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51547954&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=43fc6227-2529-4154-920e-be908af2d8b4\ncontent [신입,경력] 프론트엔드 개발자 채용 (업계 상위 연봉)\n\n[신입,경력] 프론트엔드 개발자 채용 (업계 상위 연봉)\n모집분야\n[마이크로소프트 MOU 계약 기사 보기]\n🛎️ 유의사항\n• 입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.\n• 모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."
#         }
#       }
#     }
#     grounding_chunks {
#       retrieved_context {
#         uri: "gs://job-agent-raw-json/rag-source-data/job_data_part_5.jsonl"
#         title: "job_data_part_5.jsonl"
#         text: "id 51732086\nstructData title (주)한울앤제주 총무팀 신규채용\nstructData company (주)한울앤제주\nstructData location 경기 성남시 분당구\nstructData experience 경력무관\nstructData employment_type 정규직\nstructData posted_date 2025-09-03\nstructData deadline_date 2025/10/24\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51732086&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=8989709f-86cd-40ad-b658-720d11158dc5\ncontent (주)한울앤제주 총무팀 신규채용\n\n총무팀 신규채용\n다음과 같이 유능한 인재를 채용합니다.\n미래를 함께 이끌어나갈 분들의 많은 관심과 지원 바랍니다.\n우리는 이러한 질문으로 출발했습니다.\n왜 한국인들의 인생 맥주는 수입맥주일까?\n왜 소맥 문화가 아닌 맥주만의 문화가 없을까?\n왜 맥주가 탄생하는 과정을 보여주고 알려줄 수 없을까?\n왜 우리나라에는 꼭 가보고 싶은 양조장이 없을까?\n한울앤제주가 태어난 이유인 이 질문들에 대한 답이 우리가 하는 모든 일입니다.\n세상에 질문을 던지는 사람.\n시장에 도전하는 사람.\n새로운 것을 창조해내는 사람.\n한울앤제주\n구성원들은 이런 사람입니다."
#         rag_chunk {
#           text: "id 51732086\nstructData title (주)한울앤제주 총무팀 신규채용\nstructData company (주)한울앤제주\nstructData location 경기 성남시 분당구\nstructData experience 경력무관\nstructData employment_type 정규직\nstructData posted_date 2025-09-03\nstructData deadline_date 2025/10/24\nstructData link https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51732086&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=8989709f-86cd-40ad-b658-720d11158dc5\ncontent (주)한울앤제주 총무팀 신규채용\n\n총무팀 신규채용\n다음과 같이 유능한 인재를 채용합니다.\n미래를 함께 이끌어나갈 분들의 많은 관심과 지원 바랍니다.\n우리는 이러한 질문으로 출발했습니다.\n왜 한국인들의 인생 맥주는 수입맥주일까?\n왜 소맥 문화가 아닌 맥주만의 문화가 없을까?\n왜 맥주가 탄생하는 과정을 보여주고 알려줄 수 없을까?\n왜 우리나라에는 꼭 가보고 싶은 양조장이 없을까?\n한울앤제주가 태어난 이유인 이 질문들에 대한 답이 우리가 하는 모든 일입니다.\n세상에 질문을 던지는 사람.\n시장에 도전하는 사람.\n새로운 것을 창조해내는 사람.\n한울앤제주\n구성원들은 이런 사람입니다."
#         }
#       }
#     }
#     grounding_supports {
#       segment {
#         start_index: 26
#         end_index: 850
#         text: "| 회사명 | 채용 제목 | 경력 조건 | 마감일 | 채용공고 |\n|---|---|---|---|---|\n| (주)이스트소프트 | LLM 기반 영상 번역 서비스 개발 | 경력 3~20년 | ~ 10/08(수) | [채용공고](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51781488&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=18e6e139-7f80-4c63-a5c4-611eac7d0699) |\n| (주)리앤파트너 | [국내 LegalTech기업] AI LLM 백엔드 개발자 대리급 | 경력 3~5년 | 2025/09/20 | [채용공고](https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51754147&location=ts&searchword=LLM&searchType=search&paid_fl=n&search_uuid=8989709f-86cd-40ad-b658-720d11158dc5) |\n| 법무법인와이케이 | [국내 TOP7 로펌 - 법무법인YK] AI 개발자 채용 | 신입"
#       }
#       grounding_chunk_indices: 0
#       confidence_scores: 0.656252325
#     }
#     grounding_supports {
#       segment {
#         start_index: 1444
#         end_index: 1594
#         text: "- **(주)이스트소프트:** LLM을 기반으로 영상 번역 서비스 개발자를 채용하며, LLM 관련 경력을 활용할 수 있습니다."
#       }
#       grounding_chunk_indices: 1
#       confidence_scores: 0.790905654
#     }
#     grounding_supports {
#       segment {
#         start_index: 1595
#         end_index: 1807
#         text: "- **(주)리앤파트너:** LegalTech 기업에서 AI LLM 백엔드 개발자를 채용하며, Django 기반 웹서비스와 연동되는 LLM & RAG 기반 파이프라인 설계 경험을 쌓을 수 있습니다."
#       }
#       grounding_chunk_indices: 2
#       confidence_scores: 0.622717559
#     }
#   }
#   avg_logprobs: -0.010975476946149554
# }
# usage_metadata {
#   prompt_token_count: 351
#   candidates_token_count: 875
#   total_token_count: 1226
#   prompt_tokens_details {
#     modality: TEXT
#     token_count: 351
#   }
#   candidates_tokens_details {
#     modality: TEXT
#     token_count: 875
#   }
# }
# model_version: "gemini-2.0-flash-001"
# create_time {
#   seconds: 1757928334
#   nanos: 845008000
# }
# response_id: "jtvHaNDJM_jTj_cPrOLciQU"

# %%
API_URL = "https://rag-chatbot-941837367982.us-east4.run.app/ask"
question_text = "이번 주 마감하는 서울 지역의 신입 공고 보여줘"

payload = {
    "question": question_text
}

response = requests.post(API_URL, json=payload)
response.text
# Out:
# 'null'

# %%
response
# Out:
# <Response [500]>
